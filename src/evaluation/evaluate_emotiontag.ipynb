# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import pandas as pd
import numpy as np
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from nanoGPT.chat import init_model as init_nanoGPT
from  nanoGPT.chat import respond as get_respond_nanoGPT
import torch
from bert_score import score
import tiktoken
from sklearn.metrics import classification_report, accuracy_score
# Out:
# loading GPT-2 encodings...

# %%
data_path = '../../data/emotion/validation/100_validation.csv'
df = pd.read_csv(data_path)

# %%
df.head()
# Out:
#                                            Situation grouped_emotion  \
# 0  Last night I heard strange noises coming from ...          afraid
# 1  My mom and sister threw me a baby shower when ...         excited
# 2  I just applied for a new job.  After the inter...        grateful
# 3  I loaned some money to my friend at work. Turn...         annoyed
# 4  I was out walking late last night and seen som...             NaN
#
#                                 empathetic_dialogues  \
# 0  In the middle of the night I heard some weird ...
# 1         that was very nice of them congratulations
# 2   Oh really, do you feel like you did a great job?
# 3  Wow! What a jerk for him to up and leave with ...
# 4                          Oh my god. What happened?
#
#                                               labels
# 0                       Should have grabbed the gun.
# 1  Thank you!  It was so nice, I had no idea it w...
# 2        I do!  I'm feeling very optimistic about it
# 3  It was a medium amount of money but still, he ...
# 4  Well, I started walking much faster. It looked...

# %%
model_list = {
    'single_conversation': 'block_size=64/withoutemotion/singleConversation',
    'whole_conversation':'block_size=64/withoutemotion/wholeConversation',
    'single_conversation_withemotion':'block_size=64/withemotion',
    'single_conversation_withcontext': 'block_size=64/withcontext',
    'single_conversation_withGPTdata': 'block_size=64/withoutemotion/singleConversation_withGPTdata',
    'single_conversation_withGPTdata_bs256': 'block_size=256/singleConversation_withGPTdata',
}

for model_type, model_path in model_list.items():
    model_list[model_type] = init_nanoGPT(model_path)
# Out:
# Loading model from: ../trained-saved/block_size=64/withoutemotion/singleConversation/ckpt.pt
# /Users/sofiagermer/Desktop/SOFIA/IAS/WinterSemester_24_25/ml_proj/Project-ML/src/nanoGPT/chat.py:40: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(ckpt_path, map_location=device)
# number of parameters: 3.42M
# Loading model from: ../trained-saved/block_size=64/withoutemotion/wholeConversation/ckpt.pt
# number of parameters: 3.42M
# Loading model from: ../trained-saved/block_size=64/withemotion/ckpt.pt
# number of parameters: 3.42M
# Loading model from: ../trained-saved/block_size=64/withcontext/ckpt.pt
# number of parameters: 3.42M
# Loading model from: ../trained-saved/block_size=64/withoutemotion/singleConversation_withGPTdata/ckpt.pt
# number of parameters: 3.42M
# Loading model from: ../trained-saved/block_size=256/singleConversation_withGPTdata/ckpt.pt
# number of parameters: 3.45M

# %%
def get_response_from_nanoGPT(row,model):
    emotion = row['label_emotion']
    human = row['label_output']
    start = '<bot> ' + human + '<human>'
    response, model_emotion, _ = get_respond_nanoGPT(start, 1, model=model, enable_print=True)
    print("response", response)
    print("model_emotion", model_emotion)

    return response, model_emotion

# %% [markdown]
# ## Evaluate emotion tag generation
#
# Evaluate the emotion tag generation from the model that was trained with it: single_conversation_withemotion.

# %%
df.head()

# Display the list of all columns in the DataFrame
print(df.columns.tolist())

emotion_df = df.copy()

# Remove the "Situation" column
emotion_df = emotion_df.drop(columns=["Situation"])


# Rename the column
emotion_df = emotion_df.rename(columns={"grouped_emotion": "label_emotion"})
emotion_df = emotion_df.rename(columns={"empathetic_dialogues": "input"})
emotion_df = emotion_df.rename(columns={"labels": "label_output"})
# Out:
# ['Situation', 'grouped_emotion', 'empathetic_dialogues', 'labels']

# %%
emotion_df.head()
# Out:
#   label_emotion                                              input  \
# 0        afraid  In the middle of the night I heard some weird ...
# 1       excited         that was very nice of them congratulations
# 2      grateful   Oh really, do you feel like you did a great job?
# 3       annoyed  Wow! What a jerk for him to up and leave with ...
# 4           NaN                          Oh my god. What happened?
#
#                                         label_output
# 0                       Should have grabbed the gun.
# 1  Thank you!  It was so nice, I had no idea it w...
# 2        I do!  I'm feeling very optimistic about it
# 3  It was a medium amount of money but still, he ...
# 4  Well, I started walking much faster. It looked...

# %%
print("model being used: ", 'single_conversation_withemotion')

def get_response_and_save(row, model):
    response, emotion = get_response_from_nanoGPT(row, model)
    return pd.Series([response, emotion])

model = model_list['single_conversation_withemotion']
emotion_df[['model_output', 'model_emotion']] = emotion_df.apply(lambda row: get_response_and_save(row, model), axis=1)

emotion_df['model_emotion'] = emotion_df['model_emotion'].str.strip() # remove the \n at the end
# Out:
# model being used:  single_conversation_withemotion
# output <bot> Should have grabbed the gun.<human> I saw it. I would have been so upset. <endOfText>
# <emotion> disgusted
# <bot> I was so disgusted!
# <human> I'm sorry. I hope you found a thing. <endOfText>
# <emotion> disgusted
# <bot> I was so embarrassed. I was so embarrassed. I feel bad about it.
# <human> Oh no, what happened? <endOfText>
# <emotion> disgusted
# <
# Emotion:  disgusted
#
# Robot:  I saw it. I would have been so upset.
# ----Debug: Full output---
# <bot> Should have grabbed the gun.<human> I saw it. I would have been so upset. <endOfText>
# <emotion> disgusted
# <bot> I was so disgusted!
# <human> I'm sorry. I hope you found a thing. <endOfText>
# <emotion> disgusted
# <bot> I was so embarrassed. I was so embarrassed. I feel bad about it.
# <human> Oh no, what happened? <endOfText>
# <emotion> disgusted
# <
# response  I saw it. I would have been so upset.
# model_emotion  disgusted
#
# output <bot> Thank you!  It was so nice, I had no idea it was happening.  They're not usually so good with secrets haha<human> I know, I'm so glad that I've done it. <endOfText>
# <emotion> grateful
# <bot> I have a good feeling that I am going to do well.
# <human> That's good. I hope you do well! <endOfText>
# <emotion> grateful
# <bot> I hope so. I'm sure you will get the promotion on the results.
# <human> That's great. I'm glad you are able
# Emotion:  grateful
#
# Robot:  I know, I'm so glad that I've done it.
# ----Debug: Full output---
# <bot> Thank you!  It was so nice, I had no idea it was happening.  They're not usually so good with secrets haha<human> I know, I'm so glad that I've done it. <endOfText>
# <emotion> grateful
# <bot> I have a good feeling that I am going to do well.
# <human> That's good. I hope you do well! <endOfText>
# <emotion> grateful
# <bot> I hope so. I'm sure you will get the promotion on the results.
# <human> That's great. I'm glad you are able
# response  I know, I'm so glad that I've done it.
# model_emotion  grateful
#
# output <bot> I do!  I'm feeling very optimistic about it<human> I'm glad you are okay.  How long ago was that? <endOfText>
# <emotion> grateful
# <bot> It was for a couple of days.
# <human> That's good to hear.  <endOfText>
# <emotion> grateful
# <bot> That is a great feeling.  Did you get it?
# <human> No, I knew I was going to go to the gym. <endOfText>
# <em
# Emotion:  grateful
#
# Robot:  I'm glad you are okay.  How long ago was that?
# ----Debug: Full output---
# <bot> I do!  I'm feeling very optimistic about it<human> I'm glad you are okay.  How long ago was that? <endOfText>
# <emotion> grateful
# <bot> It was for a couple of days.
# <human> That's good to hear.  <endOfText>
# <emotion> grateful
# <bot> That is a great feeling.  Did you get it?
# <human> No, I knew I was going to go to the gym. <endOfText>
# <em
# response  I'm glad you are okay.  How long ago was that?
# model_emotion  grateful
#
# output <bot> It was a medium amount of money but still, he did me so dirty.<human> Oh, was it a bad time? <endOfText>
# <emotion> disgusted
# <bot> Oh no, that must have been embarrassing.
# <human> I was. I was so embarrassed. <endOfText>
# <emotion> grateful
# <bot> I have been home for a week for my birthday tomorrow.
# <human> That is so nice. I hope you do well. <endOfText>
# <emotion> grateful
# <bot
# Emotion:  disgusted
#
# Robot:  Oh, was it a bad time?
# ----Debug: Full output---
# <bot> It was a medium amount of money but still, he did me so dirty.<human> Oh, was it a bad time? <endOfText>
# <emotion> disgusted
# <bot> Oh no, that must have been embarrassing.
# <human> I was. I was so embarrassed. <endOfText>
# <emotion> grateful
# <bot> I have been home for a week for my birthday tomorrow.
# <human> That is so nice. I hope you do well. <endOfText>
# <emotion> grateful
# <bot
# response  Oh, was it a bad time?
# model_emotion  disgusted
#
# output <bot> Well, I started walking much faster. It looked like they were carrying a weapon or something.<human> I was too scared. <endOfText>
# <emotion> afraid
# <bot> I was so scared when I was a kid.
# <human> That would be scary! Did you get to go back? <endOfText>
# <emotion> afraid
# <bot> No, I was so scared.
# <human> That sounds scary. I hope you get it. <endOfText>
# <emotion> afraid
# <bot> I am scared
# Emotion:  afraid
#
# Robot:  I was too scared.
# ----Debug: Full output---
# <bot> Well, I started walking much faster. It looked like they were carrying a weapon or something.<human> I was too scared. <endOfText>
# <emotion> afraid
# <bot> I was so scared when I was a kid.
# <human> That would be scary! Did you get to go back? <endOfText>
# <emotion> afraid
# <bot> No, I was so scared.
# <human> That sounds scary. I hope you get it. <endOfText>
# <emotion> afraid
# <bot> I am scared
# response  I was too scared.
# model_emotion  afraid
#
# output <bot> I had braces growing up too, the worst part for me was the molding!<human> I bet that was a good time. <endOfText>
# <emotion> excited
# <bot> I was shocked when I walked out of my car today.
# <human> That's awesome. Was it your friend a happy surprise? <endOfText>
# <emotion> excited
# <bot> Yes and he was so lucky. I was so happy.
# <human> That's awesome. I'm glad you were able to find him. <endOfText
# Emotion:  excited
#
# Robot:  I bet that was a good time.
# ----Debug: Full output---
# <bot> I had braces growing up too, the worst part for me was the molding!<human> I bet that was a good time. <endOfText>
# <emotion> excited
# <bot> I was shocked when I walked out of my car today.
# <human> That's awesome. Was it your friend a happy surprise? <endOfText>
# <emotion> excited
# <bot> Yes and he was so lucky. I was so happy.
# <human> That's awesome. I'm glad you were able to find him. <endOfText
# response  I bet that was a good time.
# model_emotion  excited
#
# output <bot> Yes, and it really sucks if you forget something important.<human> I was able to move out. <endOfText>
# <emotion> disappointed
# <bot> I was at the store and was all alone.
# <human> That's terrible. Did you find out what happened? <endOfText>
# <emotion> disappointed
# <bot> No, I really did not. I was so upset.
# <human> That is so sad. Did you find out why? <endOfText>
# <emotion> disappointed
# Emotion:  disappointed
#
# Robot:  I was able to move out.
# ----Debug: Full output---
# <bot> Yes, and it really sucks if you forget something important.<human> I was able to move out. <endOfText>
# <emotion> disappointed
# <bot> I was at the store and was all alone.
# <human> That's terrible. Did you find out what happened? <endOfText>
# <emotion> disappointed
# <bot> No, I really did not. I was so upset.
# <human> That is so sad. Did you find out why? <endOfText>
# <emotion> disappointed
# response  I was able to move out.
# model_emotion  disappointed
#
# output <bot> O no! That's a terrible thing to have happen or see.<human> I was so angry! <endOfText>
# <emotion> disappointed
# <bot> I was going to have my first first child.
# <human> I am sorry to hear that.  <endOfText>
# <emotion> disappointed
# <bot> It was so sad. I am so sorry for her.
# <human> Yes, it was so sad.  <endOfText>
# <emotion> grateful
# <bot> I was in a
# Emotion:  disappointed
#
# Robot:  I was so angry!
# ----Debug: Full output---
# <bot> O no! That's a terrible thing to have happen or see.<human> I was so angry! <endOfText>
# <emotion> disappointed
# <bot> I was going to have my first first child.
# <human> I am sorry to hear that.  <endOfText>
# <emotion> disappointed
# <bot> It was so sad. I am so sorry for her.
# <human> Yes, it was so sad.  <endOfText>
# <emotion> grateful
# <bot> I was in a
# response  I was so angry!
# model_emotion  disappointed
#
# output <bot> Wow, that is so disgusting.<human> I had to walk right home. <endOfText>
# <emotion> disgusted
# <bot> I was so disgusted when I was a kid.
# <human> That is so gross.  <endOfText>
# <emotion> disgusted
# <bot> I was so embarrassed.
# <human> I know right!  I was so embarrassed. <endOfText>
# <emotion> disgusted
# <bot> I was walking home today and I was so
# Emotion:  disgusted
#
# Robot:  I had to walk right home.
# ----Debug: Full output---
# <bot> Wow, that is so disgusting.<human> I had to walk right home. <endOfText>
# <emotion> disgusted
# <bot> I was so disgusted when I was a kid.
# <human> That is so gross.  <endOfText>
# <emotion> disgusted
# <bot> I was so embarrassed.
# <human> I know right!  I was so embarrassed. <endOfText>
# <emotion> disgusted
# <bot> I was walking home today and I was so
# response  I had to walk right home.
# model_emotion  disgusted
#
# output <bot> Wow.Really? What kind?<human> It was a new movie. I was thinking about the beach and my wife and I didn't know what to do with her. <endOfText>
# <emotion> prepared
# <bot> I have my final math test tomorrow. I think I am going to do well.
# <human> That's great that you did well. <endOfText>
# <emotion> prepared
# <bot> I do. I am so ready for it.
# <human> I
# Emotion:  prepared
#
# Robot:  It was a new movie. I was thinking about the beach and my wife and I didn't know what to do with her.
# ----Debug: Full output---
# <bot> Wow.Really? What kind?<human> It was a new movie. I was thinking about the beach and my wife and I didn't know what to do with her. <endOfText>
# <emotion> prepared
# <bot> I have my final math test tomorrow. I think I am going to do well.
# <human> That's great that you did well. <endOfText>
# <emotion> prepared
# <bot> I do. I am so ready for it.
# <human> I
# response  It was a new movie. I was thinking about the beach and my wife and I didn't know what to do with her.
# model_emotion  prepared
#
# output <bot> Omg my current dog does that sometimes. She pukes up bile if she doesn't eat, so I always have to make sure she is eating her food.<human> I was able to get a refund. <endOfText>
# <emotion> grateful
# <bot> I was so thankful when I got a promotion at work and was happy for my job.
# <human> That's great. I'm glad you were able to find a good job. <endOfText>
# <emotion> grateful
# <bot> I was in a car accident last week, and I'm hoping it will be a good friend.
# <human>
# Emotion:  grateful
#
# Robot:  I was able to get a refund.
# ----Debug: Full output---
# <bot> Omg my current dog does that sometimes. She pukes up bile if she doesn't eat, so I always have to make sure she is eating her food.<human> I was able to get a refund. <endOfText>
# <emotion> grateful
# <bot> I was so thankful when I got a promotion at work and was happy for my job.
# <human> That's great. I'm glad you were able to find a good job. <endOfText>
# <emotion> grateful
# <bot> I was in a car accident last week, and I'm hoping it will be a good friend.
# <human>
# response  I was able to get a refund.
# model_emotion  grateful
#
# output <bot> That's amazing, It's always nice to get on with your family! Have you always got on with them? <human> That's awesome you're getting to be able to find a good job. <endOfText>
# <emotion> prepared
# <bot> I am going to do well. I am going to do well. I have a lot of research on the job.
# <human> I bet you are excited for your work! <endOfText>
# <emotion> prepared
# <bot> I am so ready to get it done. I know I did well.
# <human
# Emotion:  prepared
#
# Robot:  That's awesome you're getting to be able to find a good job.
# ----Debug: Full output---
# <bot> That's amazing, It's always nice to get on with your family! Have you always got on with them? <human> That's awesome you're getting to be able to find a good job. <endOfText>
# <emotion> prepared
# <bot> I am going to do well. I am going to do well. I have a lot of research on the job.
# <human> I bet you are excited for your work! <endOfText>
# <emotion> prepared
# <bot> I am so ready to get it done. I know I did well.
# <human
# response  That's awesome you're getting to be able to find a good job.
# model_emotion  prepared
#
# output <bot> I am not sure as I could not stop because of all the traffic.<human> I hate that <endOfText>
# <emotion> annoyed
# <bot> What happened?
# <human> I was a lonesome do not go out and i don't know what to do <endOfText>
# <emotion> grateful
# <bot> I was really nervous and I was so happy when I got out of town.
# <human> Oh wow!  What did you do? <endOfText>
# <emotion> grateful
# <
# Emotion:  annoyed
#
# Robot:  I hate that
# ----Debug: Full output---
# <bot> I am not sure as I could not stop because of all the traffic.<human> I hate that <endOfText>
# <emotion> annoyed
# <bot> What happened?
# <human> I was a lonesome do not go out and i don't know what to do <endOfText>
# <emotion> grateful
# <bot> I was really nervous and I was so happy when I got out of town.
# <human> Oh wow!  What did you do? <endOfText>
# <emotion> grateful
# <
# response  I hate that
# model_emotion  annoyed
#
# output <bot> I can barely walk much less imagine that.<human> I'm sorry to hear that. I hope you get it soon. <endOfText>
# <emotion> disappointed
# <bot> That's so sad. I'm sorry to hear that. Are you ok?
# <human> I am fine now. I can't be the same way lol <endOfText>
# <emotion> disappointed
# <bot> I was in a bad mood yesterday.
# <human> I'm sorry you had to deal with that. <
# Emotion:  disappointed
#
# Robot:  I'm sorry to hear that. I hope you get it soon.
# ----Debug: Full output---
# <bot> I can barely walk much less imagine that.<human> I'm sorry to hear that. I hope you get it soon. <endOfText>
# <emotion> disappointed
# <bot> That's so sad. I'm sorry to hear that. Are you ok?
# <human> I am fine now. I can't be the same way lol <endOfText>
# <emotion> disappointed
# <bot> I was in a bad mood yesterday.
# <human> I'm sorry you had to deal with that. <
# response  I'm sorry to hear that. I hope you get it soon.
# model_emotion  disappointed
#
# output <bot> Oh for sure! I love riding jet skis!<human> Me too. I'm going to get back on my family, but I can't wait! <endOfText>
# <emotion> prepared
# <bot> I'm going to a concert this weekend!
# <human> That's exciting! I hope you enjoy it again! <endOfText>
# <emotion> prepared
# <bot> I have been to the beach. I'm so ready to go!
# <human> I am sure you will do well.
# Emotion:  prepared
#
# Robot:  Me too. I'm going to get back on my family, but I can't wait!
# ----Debug: Full output---
# <bot> Oh for sure! I love riding jet skis!<human> Me too. I'm going to get back on my family, but I can't wait! <endOfText>
# <emotion> prepared
# <bot> I'm going to a concert this weekend!
# <human> That's exciting! I hope you enjoy it again! <endOfText>
# <emotion> prepared
# <bot> I have been to the beach. I'm so ready to go!
# <human> I am sure you will do well.
# response  Me too. I'm going to get back on my family, but I can't wait!
# model_emotion  prepared
#
# output <bot> I feel like this is me. I'm clean, but I'm stuck with a dirty roommate who doesn't do dishes. And I also live in a place that is old and looks terrible to begin with. Sorry you have to deal with that, because I know I hate living in it!<human> I'm sorry to hear that. Just be careful to get a good friend. <endOfText>
# <emotion> disappointed
# <bot> I'm sorry to hear that. What's going on?
# <human> I don't know. I'm not sure.  I have a lot of my own myself, but I think it will be a good idea to do. <endOfText>
# <emotion> disappointed
# <bot> I was so sad when my
# Emotion:  disappointed
#
# Robot:  I'm sorry to hear that. Just be careful to get a good friend.
# ----Debug: Full output---
# <bot> I feel like this is me. I'm clean, but I'm stuck with a dirty roommate who doesn't do dishes. And I also live in a place that is old and looks terrible to begin with. Sorry you have to deal with that, because I know I hate living in it!<human> I'm sorry to hear that. Just be careful to get a good friend. <endOfText>
# <emotion> disappointed
# <bot> I'm sorry to hear that. What's going on?
# <human> I don't know. I'm not sure.  I have a lot of my own myself, but I think it will be a good idea to do. <endOfText>
# <emotion> disappointed
# <bot> I was so sad when my
# response  I'm sorry to hear that. Just be careful to get a good friend.
# model_emotion  disappointed
#
# output <bot> You can get a adviser<human> I'm way towards my friend about my car insurance.  I'm not sure if I want to be able to help my car! <endOfText>
# <emotion> disgusted
# <bot> I was in the end of the day and I was pretty upset, but I didn't think I was going to pass.
# <human> Well, I hope you didn't have to go to the doctor? <endOfText>
# <emotion> disgusted
# <bot>
# Emotion:  disgusted
#
# Robot:  I'm way towards my friend about my car insurance.  I'm not sure if I want to be able to help my car!
# ----Debug: Full output---
# <bot> You can get a adviser<human> I'm way towards my friend about my car insurance.  I'm not sure if I want to be able to help my car! <endOfText>
# <emotion> disgusted
# <bot> I was in the end of the day and I was pretty upset, but I didn't think I was going to pass.
# <human> Well, I hope you didn't have to go to the doctor? <endOfText>
# <emotion> disgusted
# <bot>
# response  I'm way towards my friend about my car insurance.  I'm not sure if I want to be able to help my car!
# model_emotion  disgusted
#
# output <bot> Yeah, Medical emergency. I borrowed $5000. Hope I'll repay this month.<human> I'm glad you got the ticket. <endOfText>
# <emotion> excited
# <bot> That's good! What a great feeling.
# <human> It was a good day.  <endOfText>
# <emotion> disgusted
# <bot> I was in a bad mood tonight!
# <human> I'm sorry you didn't get caught in a bad mood. <endOfText>
# <emotion> disgusted
# <bot> I feel
# Emotion:  excited
#
# Robot:  I'm glad you got the ticket.
# ----Debug: Full output---
# <bot> Yeah, Medical emergency. I borrowed $5000. Hope I'll repay this month.<human> I'm glad you got the ticket. <endOfText>
# <emotion> excited
# <bot> That's good! What a great feeling.
# <human> It was a good day.  <endOfText>
# <emotion> disgusted
# <bot> I was in a bad mood tonight!
# <human> I'm sorry you didn't get caught in a bad mood. <endOfText>
# <emotion> disgusted
# <bot> I feel
# response  I'm glad you got the ticket.
# model_emotion  excited
#
# output <bot> You shouldn't let those kind of people upset you.<human> Oh, I see. I'm sure that you're feeling better. <endOfText>
# <emotion> disgusted
# <bot> Oh, I'm sorry to hear that. I'm sure you'll get some good news.
# <human> I'm sure they will, I think it's better to get better. <endOfText>
# <emotion> impressed
# <bot> My brother is going to be a good friend for his senior year.
# <human>
# Emotion:  disgusted
#
# Robot:  Oh, I see. I'm sure that you're feeling better.
# ----Debug: Full output---
# <bot> You shouldn't let those kind of people upset you.<human> Oh, I see. I'm sure that you're feeling better. <endOfText>
# <emotion> disgusted
# <bot> Oh, I'm sorry to hear that. I'm sure you'll get some good news.
# <human> I'm sure they will, I think it's better to get better. <endOfText>
# <emotion> impressed
# <bot> My brother is going to be a good friend for his senior year.
# <human>
# response  Oh, I see. I'm sure that you're feeling better.
# model_emotion  disgusted
#
# output <bot> Oh no! He doesn't seem like such a good friend then. I hate it when friends pull stuff like that!<human> I don't know what I did. <endOfText>
# <emotion> disappointed
# <bot> I was so upset when my sister was in a bad place.
# <human> What happened? <endOfText>
# <emotion> disappointed
# <bot> She was going to be a party for me to get to the weekend
# <human> Oh that sounds like a fun time. <endOfText>
# <emotion> disappointed
# <bot> Yes
# Emotion:  disappointed
#
# Robot:  I don't know what I did.
# ----Debug: Full output---
# <bot> Oh no! He doesn't seem like such a good friend then. I hate it when friends pull stuff like that!<human> I don't know what I did. <endOfText>
# <emotion> disappointed
# <bot> I was so upset when my sister was in a bad place.
# <human> What happened? <endOfText>
# <emotion> disappointed
# <bot> She was going to be a party for me to get to the weekend
# <human> Oh that sounds like a fun time. <endOfText>
# <emotion> disappointed
# <bot> Yes
# response  I don't know what I did.
# model_emotion  disappointed
#
# output <bot> Ohh you have a really good memory. I am very bad at remembering things, lol.<human> I was watching the movie. <endOfText>
# <emotion> disgusted
# <bot> I was so disgusted when I went out of the bathroom and I accidentally destroyed my dog.
# <human> Oh no! Did you find him? <endOfText>
# <emotion> disgusted
# <bot> No. I was so mad.
# <human> I would have to try to get some cash. <endOfText>
# <emotion> disgusted
# <
# Emotion:  disgusted
#
# Robot:  I was watching the movie.
# ----Debug: Full output---
# <bot> Ohh you have a really good memory. I am very bad at remembering things, lol.<human> I was watching the movie. <endOfText>
# <emotion> disgusted
# <bot> I was so disgusted when I went out of the bathroom and I accidentally destroyed my dog.
# <human> Oh no! Did you find him? <endOfText>
# <emotion> disgusted
# <bot> No. I was so mad.
# <human> I would have to try to get some cash. <endOfText>
# <emotion> disgusted
# <
# response  I was watching the movie.
# model_emotion  disgusted
#
# output <bot> I wish i could make that type of money!<human> I know right? I just like the feeling of tripped. <endOfText>
# <emotion> annoyed
# <bot> I am so mad about it.
# <human> I am sure you didn't get to go to the store. <endOfText>
# <emotion> annoyed
# <bot> Oh no, that is so annoying.
# <human> It is, I'm not sure I can't even know what to do. <endOfText>
# Emotion:  annoyed
#
# Robot:  I know right? I just like the feeling of tripped.
# ----Debug: Full output---
# <bot> I wish i could make that type of money!<human> I know right? I just like the feeling of tripped. <endOfText>
# <emotion> annoyed
# <bot> I am so mad about it.
# <human> I am sure you didn't get to go to the store. <endOfText>
# <emotion> annoyed
# <bot> Oh no, that is so annoying.
# <human> It is, I'm not sure I can't even know what to do. <endOfText>
# response  I know right? I just like the feeling of tripped.
# model_emotion  annoyed
#
# output <bot> I thought we had a ghost for a long time<human> That is a good idea. I'm sure that is a lot of pain.  <endOfText>
# <emotion> disgusted
# <bot> I was at the grocery store and I had to clean up a little bit.
# <human> That is so gross! Was it a good thing? <endOfText>
# <emotion> disgusted
# <bot> It was a mess.  I felt so bad.
# <human> Oh no, that's a shame
# Emotion:  disgusted
#
# Robot:  That is a good idea. I'm sure that is a lot of pain.
# ----Debug: Full output---
# <bot> I thought we had a ghost for a long time<human> That is a good idea. I'm sure that is a lot of pain.  <endOfText>
# <emotion> disgusted
# <bot> I was at the grocery store and I had to clean up a little bit.
# <human> That is so gross! Was it a good thing? <endOfText>
# <emotion> disgusted
# <bot> It was a mess.  I felt so bad.
# <human> Oh no, that's a shame
# response  That is a good idea. I'm sure that is a lot of pain.
# model_emotion  disgusted
#
# output <bot> this is true.<human> I am so glad to hear that. <endOfText>
# <emotion> grateful
# <bot> How long ago was that?
# <human> It was a week. I was so thankful. <endOfText>
# <emotion> disappointed
# <bot> I was so upset when my dog was born. I was so upset.
# <human> That's terrible!  <endOfText>
# <emotion> disappointed
# <bot> I was.
# Emotion:  grateful
#
# Robot:  I am so glad to hear that.
# ----Debug: Full output---
# <bot> this is true.<human> I am so glad to hear that. <endOfText>
# <emotion> grateful
# <bot> How long ago was that?
# <human> It was a week. I was so thankful. <endOfText>
# <emotion> disappointed
# <bot> I was so upset when my dog was born. I was so upset.
# <human> That's terrible!  <endOfText>
# <emotion> disappointed
# <bot> I was.
# response  I am so glad to hear that.
# model_emotion  grateful
#
# output <bot> I get you, I've been in your situation before<human> I am so glad it's going to be a great weekend.  I'm sure you will be fine. <endOfText>
# <emotion> impressed
# <bot> Oh, I hope your son is well!
# <human> He is a great influence to know it. <endOfText>
# <emotion> disappointed
# <bot> I am so sorry to hear that.
# <human> It is. He is a very sick and I don't know what
# Emotion:  impressed
#
# Robot:  I am so glad it's going to be a great weekend.  I'm sure you will be fine.
# ----Debug: Full output---
# <bot> I get you, I've been in your situation before<human> I am so glad it's going to be a great weekend.  I'm sure you will be fine. <endOfText>
# <emotion> impressed
# <bot> Oh, I hope your son is well!
# <human> He is a great influence to know it. <endOfText>
# <emotion> disappointed
# <bot> I am so sorry to hear that.
# <human> It is. He is a very sick and I don't know what
# response  I am so glad it's going to be a great weekend.  I'm sure you will be fine.
# model_emotion  impressed
#
# output <bot> I see that more in the country I guess. That would be horrifying. But maybe he is just immune to pain?<human> Yes, I just don't know what to do with it. <endOfText>
# <emotion> prepared
# <bot> I got a scholarship for a promotion, it was a good feeling
# <human> That's great! I hope your luck do! <endOfText>
# <emotion> prepared
# <bot> Oh wow, I'm sure you will do well!
# <human> I am so ready to pass. <endOfText>
# <em
# Emotion:  prepared
#
# Robot:  Yes, I just don't know what to do with it.
# ----Debug: Full output---
# <bot> I see that more in the country I guess. That would be horrifying. But maybe he is just immune to pain?<human> Yes, I just don't know what to do with it. <endOfText>
# <emotion> prepared
# <bot> I got a scholarship for a promotion, it was a good feeling
# <human> That's great! I hope your luck do! <endOfText>
# <emotion> prepared
# <bot> Oh wow, I'm sure you will do well!
# <human> I am so ready to pass. <endOfText>
# <em
# response  Yes, I just don't know what to do with it.
# model_emotion  prepared
#
# output <bot> Can you tell me the name of the book? I find myself being engaged by a lot of novels these days.<human> That is good. Did you get a new one? <endOfText>
# <emotion> disappointed
# <bot> I did. I was so disappointed in myself and I was so upset.
# <human> Oh no, did you find out? <endOfText>
# <emotion> disappointed
# <bot> I did. I was so upset.
# <human> That is so sad. Did you get to go to the house with them? <endOfText
# Emotion:  disappointed
#
# Robot:  That is good. Did you get a new one?
# ----Debug: Full output---
# <bot> Can you tell me the name of the book? I find myself being engaged by a lot of novels these days.<human> That is good. Did you get a new one? <endOfText>
# <emotion> disappointed
# <bot> I did. I was so disappointed in myself and I was so upset.
# <human> Oh no, did you find out? <endOfText>
# <emotion> disappointed
# <bot> I did. I was so upset.
# <human> That is so sad. Did you get to go to the house with them? <endOfText
# response  That is good. Did you get a new one?
# model_emotion  disappointed
#
# output <bot> Wow how exciting, has he been practicing a lot? <human> He's been a year and I'm sure he'll do great! <endOfText>
# <emotion> grateful
# <bot> I got a new job, I was so glad to do it.
# <human> I'm glad you're able to find yourself. <endOfText>
# <emotion> grateful
# <bot> That's good. You are lucky!
# <human> Yes, I think I am.  I have been there 5 years now.
# Emotion:  grateful
#
# Robot:  He's been a year and I'm sure he'll do great!
# ----Debug: Full output---
# <bot> Wow how exciting, has he been practicing a lot? <human> He's been a year and I'm sure he'll do great! <endOfText>
# <emotion> grateful
# <bot> I got a new job, I was so glad to do it.
# <human> I'm glad you're able to find yourself. <endOfText>
# <emotion> grateful
# <bot> That's good. You are lucky!
# <human> Yes, I think I am.  I have been there 5 years now.
# response  He's been a year and I'm sure he'll do great!
# model_emotion  grateful
#
# output <bot> yea i was very happy he helped me<human> That's awesome! It's always nice to have good neighbors. <endOfText>
# <emotion> excited
# <bot> That's great! What a good feeling to have. I bet he feels amazing about it.
# <human> He was a good old girl. <endOfText>
# <emotion> excited
# <bot> I was so happy when my brother got his first word.
# <human> Oh I bet that was fun! <endOfText
# Emotion:  excited
#
# Robot:  That's awesome! It's always nice to have good neighbors.
# ----Debug: Full output---
# <bot> yea i was very happy he helped me<human> That's awesome! It's always nice to have good neighbors. <endOfText>
# <emotion> excited
# <bot> That's great! What a good feeling to have. I bet he feels amazing about it.
# <human> He was a good old girl. <endOfText>
# <emotion> excited
# <bot> I was so happy when my brother got his first word.
# <human> Oh I bet that was fun! <endOfText
# response  That's awesome! It's always nice to have good neighbors.
# model_emotion  excited
#
# output <bot> They wer really nice and trustworthy. I even let them use my wifi password.<human> That is really good.  <endOfText>
# <emotion> grateful
# <bot> That is great news! What kind of job is it?
# <human> It is a job for a job. <endOfText>
# <emotion> prepared
# <bot> I am getting ready for my first time. I cant wait to go to the park.
# <human> That's great! I wish you luck to get it done! <endOfText>
# Emotion:  grateful
#
# Robot:  That is really good.
# ----Debug: Full output---
# <bot> They wer really nice and trustworthy. I even let them use my wifi password.<human> That is really good.  <endOfText>
# <emotion> grateful
# <bot> That is great news! What kind of job is it?
# <human> It is a job for a job. <endOfText>
# <emotion> prepared
# <bot> I am getting ready for my first time. I cant wait to go to the park.
# <human> That's great! I wish you luck to get it done! <endOfText>
# response  That is really good.
# model_emotion  grateful
#
# output <bot> Or it could be you and a dope house party<human> It's been a week and a lot of my friends are going to be out. I am so happy. <endOfText>
# <emotion> disappointed
# <bot> I was at the grocery store and I had to cancel.
# <human> Oh no! Did you get to work? <endOfText>
# <emotion> disappointed
# <bot> I did! It was so sad when my dog came to visit me.
# <human> I am so sorry
# Emotion:  disappointed
#
# Robot:  It's been a week and a lot of my friends are going to be out. I am so happy.
# ----Debug: Full output---
# <bot> Or it could be you and a dope house party<human> It's been a week and a lot of my friends are going to be out. I am so happy. <endOfText>
# <emotion> disappointed
# <bot> I was at the grocery store and I had to cancel.
# <human> Oh no! Did you get to work? <endOfText>
# <emotion> disappointed
# <bot> I did! It was so sad when my dog came to visit me.
# <human> I am so sorry
# response  It's been a week and a lot of my friends are going to be out. I am so happy.
# model_emotion  disappointed
#
# output <bot> Yeah it might be a good idea to tell him. But you may want to have the money to give back to him first. <human> I'm sure he will. <endOfText>
# <emotion> disappointed
# <bot> I had to put my dog out at the store and I was so upset.
# <human> I'm sorry to hear that. It's hard to lose a loved one and it's a shame. <endOfText>
# <emotion> disappointed
# <bot> I'm sorry to hear that.  Is it your friend's fault?
# <human> No, but I
# Emotion:  disappointed
#
# Robot:  I'm sure he will.
# ----Debug: Full output---
# <bot> Yeah it might be a good idea to tell him. But you may want to have the money to give back to him first. <human> I'm sure he will. <endOfText>
# <emotion> disappointed
# <bot> I had to put my dog out at the store and I was so upset.
# <human> I'm sorry to hear that. It's hard to lose a loved one and it's a shame. <endOfText>
# <emotion> disappointed
# <bot> I'm sorry to hear that.  Is it your friend's fault?
# <human> No, but I
# response  I'm sure he will.
# model_emotion  disappointed
#
# output <bot> What did you do with them?<human> I think they were not good at all. <endOfText>
# <emotion> grateful
# <bot> I'm going to the dentist, I think that I will get over the weekend
# <human> I'm sorry. I hope you feel better soon! <endOfText>
# <emotion> grateful
# <bot> I hope so. I don't know what to do now.
# <human> That is so sad. I am sorry to hear that. <
# Emotion:  grateful
#
# Robot:  I think they were not good at all.
# ----Debug: Full output---
# <bot> What did you do with them?<human> I think they were not good at all. <endOfText>
# <emotion> grateful
# <bot> I'm going to the dentist, I think that I will get over the weekend
# <human> I'm sorry. I hope you feel better soon! <endOfText>
# <emotion> grateful
# <bot> I hope so. I don't know what to do now.
# <human> That is so sad. I am sorry to hear that. <
# response  I think they were not good at all.
# model_emotion  grateful
#
# output <bot> Congrats!!<human> Thanks, I am so happy with it. <endOfText>
# <emotion> prepared
# <bot> I am going to a concert this weekend.
# <human> Are you going to go to college? <endOfText>
# <emotion> prepared
# <bot> I am so ready to go on vacation. I am going to crush it
# <human> That's great! I hope you get it! <endOfText>
# <emotion> prepared
# Emotion:  prepared
#
# Robot:  Thanks, I am so happy with it.
# ----Debug: Full output---
# <bot> Congrats!!<human> Thanks, I am so happy with it. <endOfText>
# <emotion> prepared
# <bot> I am going to a concert this weekend.
# <human> Are you going to go to college? <endOfText>
# <emotion> prepared
# <bot> I am so ready to go on vacation. I am going to crush it
# <human> That's great! I hope you get it! <endOfText>
# <emotion> prepared
# response  Thanks, I am so happy with it.
# model_emotion  prepared
#
# output <bot> what was on it<human> I was just a little bit envious.  <endOfText>
# <emotion> disgusted
# <bot> I ate a whole pizza. I was so ashamed of myself.
# <human> I would be too.  Did you end up getting any good ones? <endOfText>
# <emotion> disgusted
# <bot> I did, but I was so embarrassed.
# <human> Well, it is so bad <endOfText>
# <emotion
# Emotion:  disgusted
#
# Robot:  I was just a little bit envious.
# ----Debug: Full output---
# <bot> what was on it<human> I was just a little bit envious.  <endOfText>
# <emotion> disgusted
# <bot> I ate a whole pizza. I was so ashamed of myself.
# <human> I would be too.  Did you end up getting any good ones? <endOfText>
# <emotion> disgusted
# <bot> I did, but I was so embarrassed.
# <human> Well, it is so bad <endOfText>
# <emotion
# response  I was just a little bit envious.
# model_emotion  disgusted
#
# output <bot> I am so ready for it!<human> What is the interview? <endOfText>
# <emotion> prepared
# <bot> I'm a job, but I'm not sure what I'm going to do.
# <human> That's great! It's good to have a friend that can be you. <endOfText>
# <emotion> prepared
# <bot> I'm sorry to hear that. That's rough. I'm sorry to hear that.
# <human> Thank you. I'm just
# Emotion:  prepared
#
# Robot:  What is the interview?
# ----Debug: Full output---
# <bot> I am so ready for it!<human> What is the interview? <endOfText>
# <emotion> prepared
# <bot> I'm a job, but I'm not sure what I'm going to do.
# <human> That's great! It's good to have a friend that can be you. <endOfText>
# <emotion> prepared
# <bot> I'm sorry to hear that. That's rough. I'm sorry to hear that.
# <human> Thank you. I'm just
# response  What is the interview?
# model_emotion  prepared
#
# output <bot> I am going to be a birthday clown.<human> I am so happy for my friend. <endOfText>
# <emotion> impressed
# <bot> That's nice.  What's going on?
# <human> We went to a concert once, and I was so proud of myself. <endOfText>
# <emotion> disappointed
# <bot> My brother just got a new car.
# <human> That is awesome!  I bet it was a great deal! <endOfText>
# <em
# Emotion:  impressed
#
# Robot:  I am so happy for my friend.
# ----Debug: Full output---
# <bot> I am going to be a birthday clown.<human> I am so happy for my friend. <endOfText>
# <emotion> impressed
# <bot> That's nice.  What's going on?
# <human> We went to a concert once, and I was so proud of myself. <endOfText>
# <emotion> disappointed
# <bot> My brother just got a new car.
# <human> That is awesome!  I bet it was a great deal! <endOfText>
# <em
# response  I am so happy for my friend.
# model_emotion  impressed
#
# output <bot> She was 23 years old. I got her when I was 5.<human> I bet she is! <endOfText>
# <emotion> impressed
# <bot> That is great! I bet she is a great person!
# <human> I am so happy with it! <endOfText>
# <emotion> impressed
# <bot> I am so happy for her.
# <human> I'm sure you will be able to enjoy it! <endOfText>
# <emotion> impressed
# <bot> That is great.
#
# Emotion:  impressed
#
# Robot:  I bet she is!
# ----Debug: Full output---
# <bot> She was 23 years old. I got her when I was 5.<human> I bet she is! <endOfText>
# <emotion> impressed
# <bot> That is great! I bet she is a great person!
# <human> I am so happy with it! <endOfText>
# <emotion> impressed
# <bot> I am so happy for her.
# <human> I'm sure you will be able to enjoy it! <endOfText>
# <emotion> impressed
# <bot> That is great.
#
# response  I bet she is!
# model_emotion  impressed
#
# output <bot> This was a few months ago.<human> Sounds like you had a fun experience. What did you do? <endOfText>
# <emotion> afraid
# <bot> I was thinking about going to sleep.
# <human> I think I was being so scared to go. <endOfText>
# <emotion> afraid
# <bot> I am so nervous about my job.
# <human> What kind of job? <endOfText>
# <emotion> afraid
# <bot> It was a
# Emotion:  afraid
#
# Robot:  Sounds like you had a fun experience. What did you do?
# ----Debug: Full output---
# <bot> This was a few months ago.<human> Sounds like you had a fun experience. What did you do? <endOfText>
# <emotion> afraid
# <bot> I was thinking about going to sleep.
# <human> I think I was being so scared to go. <endOfText>
# <emotion> afraid
# <bot> I am so nervous about my job.
# <human> What kind of job? <endOfText>
# <emotion> afraid
# <bot> It was a
# response  Sounds like you had a fun experience. What did you do?
# model_emotion  afraid
#
# output <bot> It's a band called Say Anything, I've been a fan of theirs since 2006! <human> Thats that is awesome.  <endOfText>
# <emotion> excited
# <bot> That's awesome! I'm sure it turned out well!
# <human> I am so happy to have them to be. <endOfText>
# <emotion> prepared
# <bot> I am going to a concert this weekend.
# <human> I am so glad you are prepared for it. <endOfText>
# <emotion> prepared
# <bot
# Emotion:  excited
#
# Robot:  Thats that is awesome.
# ----Debug: Full output---
# <bot> It's a band called Say Anything, I've been a fan of theirs since 2006! <human> Thats that is awesome.  <endOfText>
# <emotion> excited
# <bot> That's awesome! I'm sure it turned out well!
# <human> I am so happy to have them to be. <endOfText>
# <emotion> prepared
# <bot> I am going to a concert this weekend.
# <human> I am so glad you are prepared for it. <endOfText>
# <emotion> prepared
# <bot
# response  Thats that is awesome.
# model_emotion  excited
#
# output <bot> Oh that's a standard prcedure. Have you ever had one?<human> No, it's just so hard to do it. <endOfText>
# <emotion> grateful
# <bot> I was in the hospital and I was very worried about the whole time.
# <human> I'm sorry. I'm sorry to hear that. <endOfText>
# <emotion> grateful
# <bot> It can be hard to be in.
# <human> I know right. I think I'm going to be the next day. <end
# Emotion:  grateful
#
# Robot:  No, it's just so hard to do it.
# ----Debug: Full output---
# <bot> Oh that's a standard prcedure. Have you ever had one?<human> No, it's just so hard to do it. <endOfText>
# <emotion> grateful
# <bot> I was in the hospital and I was very worried about the whole time.
# <human> I'm sorry. I'm sorry to hear that. <endOfText>
# <emotion> grateful
# <bot> It can be hard to be in.
# <human> I know right. I think I'm going to be the next day. <end
# response  No, it's just so hard to do it.
# model_emotion  grateful
#
# output <bot> Have you been before? It seems like such a great way to both play and get a workout <human> That's awesome. <endOfText>
# <emotion> impressed
# <bot> I love the football season.
# <human> I love playing video games. <endOfText>
# <emotion> disappointed
# <bot> I was so happy to see the first born I had.
# <human> That is so nice. I love it when you are going to be a great day and it's good to look forward to it. <endOfText>
# <
# Emotion:  impressed
#
# Robot:  That's awesome.
# ----Debug: Full output---
# <bot> Have you been before? It seems like such a great way to both play and get a workout <human> That's awesome. <endOfText>
# <emotion> impressed
# <bot> I love the football season.
# <human> I love playing video games. <endOfText>
# <emotion> disappointed
# <bot> I was so happy to see the first born I had.
# <human> That is so nice. I love it when you are going to be a great day and it's good to look forward to it. <endOfText>
# <
# response  That's awesome.
# model_emotion  impressed
#
# output <bot> No, I hate being by myself.<human> I see, I would have done it. <endOfText>
# <emotion> disgusted
# <bot> That is a terrible thing to do.
# <human> I think I was. <endOfText>
# <emotion> disappointed
# <bot> I was so disappointed when I was a kid I saw a movie.
# <human> That's so sad. I hope your dog is ok. <endOfText>
# <emotion> disappointed
# <bot
# Emotion:  disgusted
#
# Robot:  I see, I would have done it.
# ----Debug: Full output---
# <bot> No, I hate being by myself.<human> I see, I would have done it. <endOfText>
# <emotion> disgusted
# <bot> That is a terrible thing to do.
# <human> I think I was. <endOfText>
# <emotion> disappointed
# <bot> I was so disappointed when I was a kid I saw a movie.
# <human> That's so sad. I hope your dog is ok. <endOfText>
# <emotion> disappointed
# <bot
# response  I see, I would have done it.
# model_emotion  disgusted
#
# output <bot> I could see that happening but sounds like you were super brave.<human> lol! I bet your excited! <endOfText>
# <emotion> excited
# <bot> It was a nice surprise. It was so nice to see what a surprise me.
# <human> I bet. I hope you have a good time! <endOfText>
# <emotion> excited
# <bot> That's awesome! What was the name of the class?
# <human> It was a final exam and I was so happy. <endOfText
# Emotion:  excited
#
# Robot:  lol! I bet your excited!
# ----Debug: Full output---
# <bot> I could see that happening but sounds like you were super brave.<human> lol! I bet your excited! <endOfText>
# <emotion> excited
# <bot> It was a nice surprise. It was so nice to see what a surprise me.
# <human> I bet. I hope you have a good time! <endOfText>
# <emotion> excited
# <bot> That's awesome! What was the name of the class?
# <human> It was a final exam and I was so happy. <endOfText
# response  lol! I bet your excited!
# model_emotion  excited
#
# output <bot> He's quite the piece of garbage.<human> I see. Did you ever get it? <endOfText>
# <emotion> disgusted
# <bot> Oh my lord. Did you confront him?
# <human> I did. I was so embarrassed. <endOfText>
# <emotion> afraid
# <bot> I was so scared to death. I thought I was going to get to see him.
# <human> That's terrible. Did you ever get any of the dog? <endOfText>
# Emotion:  disgusted
#
# Robot:  I see. Did you ever get it?
# ----Debug: Full output---
# <bot> He's quite the piece of garbage.<human> I see. Did you ever get it? <endOfText>
# <emotion> disgusted
# <bot> Oh my lord. Did you confront him?
# <human> I did. I was so embarrassed. <endOfText>
# <emotion> afraid
# <bot> I was so scared to death. I thought I was going to get to see him.
# <human> That's terrible. Did you ever get any of the dog? <endOfText>
# response  I see. Did you ever get it?
# model_emotion  disgusted
#
# output <bot> Tell me about it. How long have you been job hunting for?<human> We have been together for 4 months and I am so ready to get the job. <endOfText>
# <emotion> grateful
# <bot> I am going to a new job and I am so happy about my job. I think I will be able to get the promotion.
# <human> I bet you are proud! <endOfText>
# <emotion> grateful
# <bot> I am. I have a little baby.
# <human> I'm sorry
# Emotion:  grateful
#
# Robot:  We have been together for 4 months and I am so ready to get the job.
# ----Debug: Full output---
# <bot> Tell me about it. How long have you been job hunting for?<human> We have been together for 4 months and I am so ready to get the job. <endOfText>
# <emotion> grateful
# <bot> I am going to a new job and I am so happy about my job. I think I will be able to get the promotion.
# <human> I bet you are proud! <endOfText>
# <emotion> grateful
# <bot> I am. I have a little baby.
# <human> I'm sorry
# response  We have been together for 4 months and I am so ready to get the job.
# model_emotion  grateful
#
# output <bot> That is such a beautiful memory to have. I love that we forever have moments like this... How cool Hong Kong! <human> <endOfText>
# <emotion> disappointed
# <bot> I had to go to have a feeling like I had a good time of being a kid, and it's a very nostalgic to think so.
# <human> I'm sorry to hear that. What's going on? <endOfText>
# <emotion> disappointed
# <bot> I'm not sure. But I'm still looking forward to it.
# <human> I'm sorry to hear that.
# Emotion:  disappointed
#
# Robot:
# ----Debug: Full output---
# <bot> That is such a beautiful memory to have. I love that we forever have moments like this... How cool Hong Kong! <human> <endOfText>
# <emotion> disappointed
# <bot> I had to go to have a feeling like I had a good time of being a kid, and it's a very nostalgic to think so.
# <human> I'm sorry to hear that. What's going on? <endOfText>
# <emotion> disappointed
# <bot> I'm not sure. But I'm still looking forward to it.
# <human> I'm sorry to hear that.
# response
# model_emotion  disappointed
#
# output <bot> I think he was slightly over the limit but he had a few drinks earlier, so I felt a bit uncomfortable.<human> I bet he was! <endOfText>
# <emotion> disgusted
# <bot> That is awful! Did you get it back?
# <human> No, I was so mad. He was so grossed out. <endOfText>
# <emotion> disappointed
# <bot> I was watching some old roller coaster last night.
# <human> Oh no! I hope you didn't get hurt. <endOfText>
# <emotion> disappointed
#
# Emotion:  disgusted
#
# Robot:  I bet he was!
# ----Debug: Full output---
# <bot> I think he was slightly over the limit but he had a few drinks earlier, so I felt a bit uncomfortable.<human> I bet he was! <endOfText>
# <emotion> disgusted
# <bot> That is awful! Did you get it back?
# <human> No, I was so mad. He was so grossed out. <endOfText>
# <emotion> disappointed
# <bot> I was watching some old roller coaster last night.
# <human> Oh no! I hope you didn't get hurt. <endOfText>
# <emotion> disappointed
#
# response  I bet he was!
# model_emotion  disgusted
#
# output <bot> IT is. <human> I hope you find someone better right now. <endOfText>
# <emotion> grateful
# <bot> That's great! I'm glad you are very proud of him.
# <human> I am. I am so proud of him. <endOfText>
# <emotion> annoyed
# <bot> I was so mad when my brother got into work that I was in work.
# <human> I'm sorry to hear that. <endOfText>
#
# Emotion:  grateful
#
# Robot:  I hope you find someone better right now.
# ----Debug: Full output---
# <bot> IT is. <human> I hope you find someone better right now. <endOfText>
# <emotion> grateful
# <bot> That's great! I'm glad you are very proud of him.
# <human> I am. I am so proud of him. <endOfText>
# <emotion> annoyed
# <bot> I was so mad when my brother got into work that I was in work.
# <human> I'm sorry to hear that. <endOfText>
#
# response  I hope you find someone better right now.
# model_emotion  grateful
#
# output <bot> OH that sucks.<human> Oh no! I'm sorry to hear that. I don't know what to do about it. <endOfText>
# <emotion> grateful
# <bot> I am sorry to hear that.  Did you find the person or someone?
# <human> I did but I was so thankful for it. <endOfText>
# <emotion> disappointed
# <bot> I was at the store the other day and it was a little sad
# <human> I'm
# Emotion:  grateful
#
# Robot:  Oh no! I'm sorry to hear that. I don't know what to do about it.
# ----Debug: Full output---
# <bot> OH that sucks.<human> Oh no! I'm sorry to hear that. I don't know what to do about it. <endOfText>
# <emotion> grateful
# <bot> I am sorry to hear that.  Did you find the person or someone?
# <human> I did but I was so thankful for it. <endOfText>
# <emotion> disappointed
# <bot> I was at the store the other day and it was a little sad
# <human> I'm
# response  Oh no! I'm sorry to hear that. I don't know what to do about it.
# model_emotion  grateful
#
# output <bot> thats wonderful<human> I agree, I am so happy for him. <endOfText>
# <emotion> grateful
# <bot> I am so thankful for my wife
# <human> That's awesome. I love my husband! <endOfText>
# <emotion> grateful
# <bot> That's good, I'm sure he will do well!
# <human> He is a good person, and he's always there for me. <endOfText>
# <emotion>
# Emotion:  grateful
#
# Robot:  I agree, I am so happy for him.
# ----Debug: Full output---
# <bot> thats wonderful<human> I agree, I am so happy for him. <endOfText>
# <emotion> grateful
# <bot> I am so thankful for my wife
# <human> That's awesome. I love my husband! <endOfText>
# <emotion> grateful
# <bot> That's good, I'm sure he will do well!
# <human> He is a good person, and he's always there for me. <endOfText>
# <emotion>
# response  I agree, I am so happy for him.
# model_emotion  grateful
#
# ...
# <emotion> disgusted
# <bot> Oh no, did you get caught?
# <human> No, I felt bad that I was trying to get a promotion for my friend. <endOfText>
# <emotion> afraid
# <bot> I am worried that I am going to be over the weekend.
# <human> Oh no!  Are you feeling a bit nervous? <endOf
# Emotion:  disgusted
#
# Robot:  I'm glad you had to go through that.
# ----Debug: Full output---
# <bot> I don't know yet. Kinda need some time to process this.<human> I'm glad you had to go through that. <endOfText>
# <emotion> disgusted
# <bot> Oh no, did you get caught?
# <human> No, I felt bad that I was trying to get a promotion for my friend. <endOfText>
# <emotion> afraid
# <bot> I am worried that I am going to be over the weekend.
# <human> Oh no!  Are you feeling a bit nervous? <endOf
# response  I'm glad you had to go through that.
# model_emotion  disgusted
#
# output <bot> It feels so good to update/upgrade, doesn't it? I feel like I have been out of the loop for too long.<human> I'm glad you have it. <endOfText>
# <emotion> disappointed
# <bot> I'm sorry to hear that.
# <human> It's okay but I'm not sure it happens. It is not a good thing that happens. <endOfText>
# <emotion> disappointed
# <bot> I am sorry to hear that.  Are you going to see them again?
# <human> No, I am so sorry. I feel bad about it
# Emotion:  disappointed
#
# Robot:  I'm glad you have it.
# ----Debug: Full output---
# <bot> It feels so good to update/upgrade, doesn't it? I feel like I have been out of the loop for too long.<human> I'm glad you have it. <endOfText>
# <emotion> disappointed
# <bot> I'm sorry to hear that.
# <human> It's okay but I'm not sure it happens. It is not a good thing that happens. <endOfText>
# <emotion> disappointed
# <bot> I am sorry to hear that.  Are you going to see them again?
# <human> No, I am so sorry. I feel bad about it
# response  I'm glad you have it.
# model_emotion  disappointed
#
# output <bot> Yeah it hurt and I was listening to music so I might have yelled a cuss word loudly.<human> I would be happy to have time to go on a date for the day! <endOfText>
# <emotion> disappointed
# <bot> That's so sad, I hope you find it!
# <human> Thank you! I'm so sorry. It's hard to find someone that can help you. <endOfText>
# <emotion> disappointed
# <bot> I am sorry to hear that. I hope it all goes well.
# <human> Thanks,
# Emotion:  disappointed
#
# Robot:  I would be happy to have time to go on a date for the day!
# ----Debug: Full output---
# <bot> Yeah it hurt and I was listening to music so I might have yelled a cuss word loudly.<human> I would be happy to have time to go on a date for the day! <endOfText>
# <emotion> disappointed
# <bot> That's so sad, I hope you find it!
# <human> Thank you! I'm so sorry. It's hard to find someone that can help you. <endOfText>
# <emotion> disappointed
# <bot> I am sorry to hear that. I hope it all goes well.
# <human> Thanks,
# response  I would be happy to have time to go on a date for the day!
# model_emotion  disappointed
#
# output <bot> I cannot imagine anyone wanting to drink that without losing a bet<human> I know!  I was so glad that I was able to do that.  I was so happy that I didn't get to go to the store. <endOfText>
# <emotion> disappointed
# <bot> I am sorry to hear that.  Did you find something to take it?
# <human> No, I was so upset. <endOfText>
# <emotion> disappointed
# <bot> I was so sad when I saw a dog watching a
# Emotion:  disappointed
#
# Robot:  I know!  I was so glad that I was able to do that.  I was so happy that I didn't get to go to the store.
# ----Debug: Full output---
# <bot> I cannot imagine anyone wanting to drink that without losing a bet<human> I know!  I was so glad that I was able to do that.  I was so happy that I didn't get to go to the store. <endOfText>
# <emotion> disappointed
# <bot> I am sorry to hear that.  Did you find something to take it?
# <human> No, I was so upset. <endOfText>
# <emotion> disappointed
# <bot> I was so sad when I saw a dog watching a
# response  I know!  I was so glad that I was able to do that.  I was so happy that I didn't get to go to the store.
# model_emotion  disappointed
#
# output <bot> Im taking your advice and putting it into practice tomorrow!<human> I am so glad to hear that. <endOfText>
# <emotion> grateful
# <bot> I am so thankful for what a gift.
# <human> I know that feeling.  I'm not sure if I'm not a bridesmaid and's friend to family. <endOfText>
# <emotion> grateful
# <bot> I am so thankful for my friend.
# <human> That's good.  Did you ask him? <endOf
# Emotion:  grateful
#
# Robot:  I am so glad to hear that.
# ----Debug: Full output---
# <bot> Im taking your advice and putting it into practice tomorrow!<human> I am so glad to hear that. <endOfText>
# <emotion> grateful
# <bot> I am so thankful for what a gift.
# <human> I know that feeling.  I'm not sure if I'm not a bridesmaid and's friend to family. <endOfText>
# <emotion> grateful
# <bot> I am so thankful for my friend.
# <human> That's good.  Did you ask him? <endOf
# response  I am so glad to hear that.
# model_emotion  grateful
#
# output <bot> Thank you, the bracelet means a lot to me<human> That is great.  Did you get a chance to go to the doctor and get something else? <endOfText>
# <emotion> grateful
# <bot> I hope it's not too late.
# <human> You can't do that, it's not good to be able to <endOfText>
# <emotion> grateful
# <bot> That is really nice of you. Do you guys still have any pets?
# <human> I do, I think
# Emotion:  grateful
#
# Robot:  That is great.  Did you get a chance to go to the doctor and get something else?
# ----Debug: Full output---
# <bot> Thank you, the bracelet means a lot to me<human> That is great.  Did you get a chance to go to the doctor and get something else? <endOfText>
# <emotion> grateful
# <bot> I hope it's not too late.
# <human> You can't do that, it's not good to be able to <endOfText>
# <emotion> grateful
# <bot> That is really nice of you. Do you guys still have any pets?
# <human> I do, I think
# response  That is great.  Did you get a chance to go to the doctor and get something else?
# model_emotion  grateful
#
# output <bot> How terrible! I'm so sorry that happened. How long ago was it?<human> I was pretty upset, but it was a pretty bad feeling. <endOfText>
# <emotion> grateful
# <bot> I was very upset when my dog got out
# <human> Oh no!  Did you find a person? <endOfText>
# <emotion> grateful
# <bot> I did, I was so thankful for him to have someone to help you.
# <human> That's good.  How did your friend react? <endOf
# Emotion:  grateful
#
# Robot:  I was pretty upset, but it was a pretty bad feeling.
# ----Debug: Full output---
# <bot> How terrible! I'm so sorry that happened. How long ago was it?<human> I was pretty upset, but it was a pretty bad feeling. <endOfText>
# <emotion> grateful
# <bot> I was very upset when my dog got out
# <human> Oh no!  Did you find a person? <endOfText>
# <emotion> grateful
# <bot> I did, I was so thankful for him to have someone to help you.
# <human> That's good.  How did your friend react? <endOf
# response  I was pretty upset, but it was a pretty bad feeling.
# model_emotion  grateful
#
# output <bot> That's awesome! It really pays not to burn bridges, you never know when someone from your past can help you out like that.<human> That's a good thing to deal. I'm glad you're safe. <endOfText>
# <emotion> grateful
# <bot> I'm sorry to hear that. What happened?
# <human> I was a coworker that I had to cancel. I was so worried about it. <endOfText>
# <emotion> prepared
# <bot> I've got to this job interview tomorrow.
# <human> That's good. I hope you get it done
# Emotion:  grateful
#
# Robot:  That's a good thing to deal. I'm glad you're safe.
# ----Debug: Full output---
# <bot> That's awesome! It really pays not to burn bridges, you never know when someone from your past can help you out like that.<human> That's a good thing to deal. I'm glad you're safe. <endOfText>
# <emotion> grateful
# <bot> I'm sorry to hear that. What happened?
# <human> I was a coworker that I had to cancel. I was so worried about it. <endOfText>
# <emotion> prepared
# <bot> I've got to this job interview tomorrow.
# <human> That's good. I hope you get it done
# response  That's a good thing to deal. I'm glad you're safe.
# model_emotion  grateful
#
# output <bot> What did you eat?<human> I was eating a little coffee and I got some food. <endOfText>
# <emotion> disappointed
# <bot> I was at the mall and my friends were getting married.
# <human> That is so sad. I am sorry to hear that. <endOfText>
# <emotion> disappointed
# <bot> Yes, it's been a long time for me. I am so upset about it.
# <human> I'm sorry to hear that, I
# Emotion:  disappointed
#
# Robot:  I was eating a little coffee and I got some food.
# ----Debug: Full output---
# <bot> What did you eat?<human> I was eating a little coffee and I got some food. <endOfText>
# <emotion> disappointed
# <bot> I was at the mall and my friends were getting married.
# <human> That is so sad. I am sorry to hear that. <endOfText>
# <emotion> disappointed
# <bot> Yes, it's been a long time for me. I am so upset about it.
# <human> I'm sorry to hear that, I
# response  I was eating a little coffee and I got some food.
# model_emotion  disappointed
#
# output <bot> wow good for you man<human> Yes, I am so thankful for my wife. <endOfText>
# <emotion> disappointed
# <bot> I have never been to a new city and I have to go to the beach.
# <human> I'm sorry to hear that. I'm sorry to hear that. <endOfText>
# <emotion> disappointed
# <bot> Yeah it's hard to find someone. It's hard to stay home.
# <human> I'm sorry you have to
# Emotion:  disappointed
#
# Robot:  Yes, I am so thankful for my wife.
# ----Debug: Full output---
# <bot> wow good for you man<human> Yes, I am so thankful for my wife. <endOfText>
# <emotion> disappointed
# <bot> I have never been to a new city and I have to go to the beach.
# <human> I'm sorry to hear that. I'm sorry to hear that. <endOfText>
# <emotion> disappointed
# <bot> Yeah it's hard to find someone. It's hard to stay home.
# <human> I'm sorry you have to
# response  Yes, I am so thankful for my wife.
# model_emotion  disappointed
#
# output <bot> Investigate that right now! You need to know<human> Yes, I do, I just don't like the sound like a little girl. <endOfText>
# <emotion> disappointed
# <bot> I miss my family when I was younger and I was a little bit alone.
# <human> I am sorry to hear that. Did you find some friends or friends? <endOfText>
# <emotion> disappointed
# <bot> Not yet, but I am so disappointed.
# <human> That's good. I
# Emotion:  disappointed
#
# Robot:  Yes, I do, I just don't like the sound like a little girl.
# ----Debug: Full output---
# <bot> Investigate that right now! You need to know<human> Yes, I do, I just don't like the sound like a little girl. <endOfText>
# <emotion> disappointed
# <bot> I miss my family when I was younger and I was a little bit alone.
# <human> I am sorry to hear that. Did you find some friends or friends? <endOfText>
# <emotion> disappointed
# <bot> Not yet, but I am so disappointed.
# <human> That's good. I
# response  Yes, I do, I just don't like the sound like a little girl.
# model_emotion  disappointed
#
# output <bot> That's really special, and a great attitude to have<human> Well, I'm so glad I'm not going to be able to get the promotion. I'm sure I'll get it. <endOfText>
# <emotion> disappointed
# <bot> I'm sorry I'm sorry to hear that. I hope you find something better now!
# <human> I'm not sure. I'm not sure if I will be able to. <endOfText>
# <emotion> disappointed
# <bot> I'm sorry to hear that
# Emotion:  disappointed
#
# Robot:  Well, I'm so glad I'm not going to be able to get the promotion. I'm sure I'll get it.
# ----Debug: Full output---
# <bot> That's really special, and a great attitude to have<human> Well, I'm so glad I'm not going to be able to get the promotion. I'm sure I'll get it. <endOfText>
# <emotion> disappointed
# <bot> I'm sorry I'm sorry to hear that. I hope you find something better now!
# <human> I'm not sure. I'm not sure if I will be able to. <endOfText>
# <emotion> disappointed
# <bot> I'm sorry to hear that
# response  Well, I'm so glad I'm not going to be able to get the promotion. I'm sure I'll get it.
# model_emotion  disappointed
#
# output <bot> I've never watched a single full star wars movie, just bits and pieces haha<human> I've never heard of it but I think I'm going to eat a pizza and it's like a large pizza! <endOfText>
# <emotion> disappointed
# <bot> I am sorry to hear that.  Is it a good thing?
# <human> I am so sorry to hear that. It is so hard to find someone to help you. <endOfText>
# <emotion> disappointed
# <bot> I was at the grocery store the other day
# Emotion:  disappointed
#
# Robot:  I've never heard of it but I think I'm going to eat a pizza and it's like a large pizza!
# ----Debug: Full output---
# <bot> I've never watched a single full star wars movie, just bits and pieces haha<human> I've never heard of it but I think I'm going to eat a pizza and it's like a large pizza! <endOfText>
# <emotion> disappointed
# <bot> I am sorry to hear that.  Is it a good thing?
# <human> I am so sorry to hear that. It is so hard to find someone to help you. <endOfText>
# <emotion> disappointed
# <bot> I was at the grocery store the other day
# response  I've never heard of it but I think I'm going to eat a pizza and it's like a large pizza!
# model_emotion  disappointed
#
# output <bot> Me too! It seems like such a huge accomplishment at the time, doesn't it?<human> I have not, but I am so glad you are doing well. <endOfText>
# <emotion> impressed
# <bot> I am so proud of myself. I love my son!
# <human> I bet he will! <endOfText>
# <emotion> impressed
# <bot> He is a good kid.
# <human> I think he was the only one that is his first word. <endOfText>
# <emotion> impressed
#
# Emotion:  impressed
#
# Robot:  I have not, but I am so glad you are doing well.
# ----Debug: Full output---
# <bot> Me too! It seems like such a huge accomplishment at the time, doesn't it?<human> I have not, but I am so glad you are doing well. <endOfText>
# <emotion> impressed
# <bot> I am so proud of myself. I love my son!
# <human> I bet he will! <endOfText>
# <emotion> impressed
# <bot> He is a good kid.
# <human> I think he was the only one that is his first word. <endOfText>
# <emotion> impressed
#
# response  I have not, but I am so glad you are doing well.
# model_emotion  impressed
#
# output <bot> That's great! good luck<human> Thanks, it is.  I am very excited. <endOfText>
# <emotion> excited
# <bot> I got a new job interview today.
# <human> That's good. I hope you get it! <endOfText>
# <emotion> excited
# <bot> That's awesome! I'm so excited to get a new job.
# <human> That's good!  I hope you get it! <endOfText>
# <em
# Emotion:  excited
#
# Robot:  Thanks, it is.  I am very excited.
# ----Debug: Full output---
# <bot> That's great! good luck<human> Thanks, it is.  I am very excited. <endOfText>
# <emotion> excited
# <bot> I got a new job interview today.
# <human> That's good. I hope you get it! <endOfText>
# <emotion> excited
# <bot> That's awesome! I'm so excited to get a new job.
# <human> That's good!  I hope you get it! <endOfText>
# <em
# response  Thanks, it is.  I am very excited.
# model_emotion  excited
#
# output <bot> No not at all. I just got up and couldnt stop laughing at myself. I could feel the heat coming off of my face.<human> Oh my goodness! I am so sorry. I am so sorry to hear that. <endOfText>
# <emotion> disappointed
# <bot> It's okay. It's been a week and I think the whole thing is.  I'm not sure.
# <human> I know, it's a lot of people, but you can't tell you. <endOfText>
# <emotion> disappointed
# <bot> That is so sad. I hope you find
# Emotion:  disappointed
#
# Robot:  Oh my goodness! I am so sorry. I am so sorry to hear that.
# ----Debug: Full output---
# <bot> No not at all. I just got up and couldnt stop laughing at myself. I could feel the heat coming off of my face.<human> Oh my goodness! I am so sorry. I am so sorry to hear that. <endOfText>
# <emotion> disappointed
# <bot> It's okay. It's been a week and I think the whole thing is.  I'm not sure.
# <human> I know, it's a lot of people, but you can't tell you. <endOfText>
# <emotion> disappointed
# <bot> That is so sad. I hope you find
# response  Oh my goodness! I am so sorry. I am so sorry to hear that.
# model_emotion  disappointed

# %%
# print number of rows of emotion dataframe
print("Number of rows in emotion dataframe: ", len(emotion_df))
# Out:
# Number of rows in emotion dataframe:  100

# %%
new_order = ['input', 'label_output', 'model_output', 'label_emotion', 'model_emotion']  # Replace with your desired column order
emotion_df = emotion_df[new_order]

emotion_df.head(30)
# Out:
#                                                 input  \
# 0   In the middle of the night I heard some weird ...
# 1          that was very nice of them congratulations
# 2    Oh really, do you feel like you did a great job?
# 3   Wow! What a jerk for him to up and leave with ...
# 4                           Oh my god. What happened?
# 5   Yeah, it was the orthodontist but my teeth are...
# 6   That's a good idea. There's a lot of preparati...
# 7   Yesterday, I was crossing the street and the p...
# 8                    It was filled with used diapers!
# 9                         Last christmas i got a car!
# 10  Have you ever had a dog that got sick and vomi...
# 11  "Am very happy to have the best family in the ...
# 12    That is so sad. Did the kitten die? I hope not.
# 13  I was super impressed. He must have been a gym...
# 14  I have a jet ski.  It is a blast to ride on th...
# 15  I was at a friends house and he had the grosse...
# 16                    It is, I don't know what to do.
# 17  Were you in a tight spot? How much did you bor...
# 18  I'm quite upset at those I know that complain ...
# 19  I wanted a friend to help me to move to my new...
# 20  The Colts did! But I was so excited when Devin...
# 21  This may sound narcissistic and just plain wei...
# 22  Did you think a ghoul or monster were in there...
# 23                 Yes, those were the good old days!
# 24  Yeah but I've been alone so much lately. I rea...
# 25  I was riding the train today, and some guy jus...
# 26  i wanted to finish the book today, and i'm afr...
# 27    It's his first time trying yes, junior hockey./
# 28   That is a very nice friend. Moving is hard work.
# 29                          Was there any reason why?
#
#                                          label_output  \
# 0                        Should have grabbed the gun.
# 1   Thank you!  It was so nice, I had no idea it w...
# 2         I do!  I'm feeling very optimistic about it
# 3   It was a medium amount of money but still, he ...
# 4   Well, I started walking much faster. It looked...
# 5   I had braces growing up too, the worst part fo...
# 6   Yes, and it really sucks if you forget somethi...
# 7   O no! That's a terrible thing to have happen o...
# 8                         Wow, that is so disgusting.
# 9                              Wow.Really? What kind?
# 10  Omg my current dog does that sometimes. She pu...
# 11  That's amazing, It's always nice to get on wit...
# 12  I am not sure as I could not stop because of a...
# 13          I can barely walk much less imagine that.
# 14               Oh for sure! I love riding jet skis!
# 15  I feel like this is me. I'm clean, but I'm stu...
# 16                              You can get a adviser
# 17  Yeah, Medical emergency. I borrowed $5000. Hop...
# 18  You shouldn't let those kind of people upset you.
# 19  Oh no! He doesn't seem like such a good friend...
# 20  Ohh you have a really good memory. I am very b...
# 21            I wish i could make that type of money!
# 22           I thought we had a ghost for a long time
# 23                                      this is true.
# 24      I get you, I've been in your situation before
# 25  I see that more in the country I guess. That w...
# 26  Can you tell me the name of the book? I find m...
# 27   Wow how exciting, has he been practicing a lot?
# 28                  yea i was very happy he helped me
# 29  They wer really nice and trustworthy. I even l...
#
#                                          model_output label_emotion  \
# 0              I saw it. I would have been so upset.         afraid
# 1             I know, I'm so glad that I've done it.        excited
# 2     I'm glad you are okay.  How long ago was that?       grateful
# 3                             Oh, was it a bad time?        annoyed
# 4                                  I was too scared.            NaN
# 5                        I bet that was a good time.       grateful
# 6                            I was able to move out.       prepared
# 7                                    I was so angry!            NaN
# 8                          I had to walk right home.      disgusted
# 9    It was a new movie. I was thinking about the ...       excited
# 10                       I was able to get a refund.      disgusted
# 11   That's awesome you're getting to be able to f...       excited
# 12                                       I hate that   disappointed
# 13   I'm sorry to hear that. I hope you get it soon.      impressed
# 14   Me too. I'm going to get back on my family, b...           NaN
# 15   I'm sorry to hear that. Just be careful to ge...     disgusted
# 16   I'm way towards my friend about my car insura...     disgusted
# 17                      I'm glad you got the ticket.       grateful
# 18   Oh, I see. I'm sure that you're feeling better.        annoyed
# 19                          I don't know what I did.   disappointed
# 20                         I was watching the movie.       grateful
# 21   I know right? I just like the feeling of trip...       annoyed
# 22   That is a good idea. I'm sure that is a lot o...        afraid
# 23                        I am so glad to hear that.   disappointed
# 24   I am so glad it's going to be a great weekend...  disappointed
# 25        Yes, I just don't know what to do with it.      disgusted
# 26              That is good. Did you get a new one?            NaN
# 27     He's been a year and I'm sure he'll do great!      impressed
# 28   That's awesome! It's always nice to have good...      grateful
# 29                             That is really good.       disgusted
#
#    model_emotion
# 0      disgusted
# 1       grateful
# 2       grateful
# 3      disgusted
# 4         afraid
# 5        excited
# 6   disappointed
# 7   disappointed
# 8      disgusted
# 9       prepared
# 10      grateful
# 11      prepared
# 12       annoyed
# 13  disappointed
# 14      prepared
# 15  disappointed
# 16     disgusted
# 17       excited
# 18     disgusted
# 19  disappointed
# 20     disgusted
# 21       annoyed
# 22     disgusted
# 23      grateful
# 24     impressed
# 25      prepared
# 26  disappointed
# 27      grateful
# 28       excited
# 29      grateful

# %%
unique_emotions = emotion_df['label_emotion'].dropna().unique()
print("Emotions in 'label_emotion':")
for emotion in unique_emotions:
    print(emotion)

print("")
unique_emotions = emotion_df['model_emotion'].dropna().unique()
print("Emotions in 'model_emotion':")
for emotion in unique_emotions:
    print(emotion)
# Out:
# Emotions in 'label_emotion':
# afraid
# excited
# grateful
# annoyed
# prepared
# disgusted
# disappointed
# impressed
#
# Emotions in 'model_emotion':
# disgusted
# grateful
# afraid
# excited
# disappointed
# prepared
# annoyed
# impressed

# %%
# Identify instances where the values differ
differences = emotion_df[emotion_df['label_emotion'] != emotion_df['model_emotion']]

# %%
def evaluate_emotion_tags(reference, candidate):
    if len(reference) != len(candidate):
        raise ValueError("The length of reference and candidate arrays must be the same.")

    # Compute accuracy
    accuracy = accuracy_score(reference, candidate)

    # Generate classification report
    class_report = classification_report(reference, candidate, output_dict=True)

    # Extract precision, recall, and F1-score (macro-average)
    precision = class_report['macro avg']['precision']
    recall = class_report['macro avg']['recall']
    f1_score = class_report['macro avg']['f1-score']

    return {
        "accuracy": accuracy,
        "precision": precision,
        "recall": recall,
        "f1_score": f1_score,
        "classification_report": class_report
    }

# Replace NaN or invalid values in reference and candidate arrays
emotion_df['label_emotion'] = emotion_df['label_emotion'].astype(str).fillna('Unknown')
emotion_df['model_emotion'] = emotion_df['model_emotion'].astype(str).fillna('Unknown')

# Reconstruct arrays after cleaning
reference = emotion_df['label_emotion'].values
candidate = emotion_df['model_emotion'].values

# Call the function again
results = evaluate_emotion_tags(reference, candidate)

# Print results
print("Evaluation Results:")
print("Accuracy:", results['accuracy'])
print("Precision:", results['precision'])
print("Recall:", results['recall'])
print("F1-Score:", results['f1_score'])
# Out:
# Evaluation Results:
# Accuracy: 0.18
# Precision: 0.14819732736399402
# Recall: 0.15104656552024975
# F1-Score: 0.14042327809975966
# /opt/anaconda3/envs/ml/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/ml/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/ml/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
